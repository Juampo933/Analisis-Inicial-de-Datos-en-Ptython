# %% [markdown]
# <a href="https://colab.research.google.com/github/Juampo933/Juampo933/blob/main/An%C3%A1lisis_Inicial_de_Gr%C3%A1ficos_en_Python_Visualizaciones_Ejercicios_DF_Lluvias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis Inicial de Gráficos en Python
# # Precipitaciones Acumuladas

# %% [markdown]
# *Este notebook cuenta con la intencion de servir como introducción en el análisis de datos con python, utilizando las librerias de matplotlib como principal recurso.*
#
# *Su complejidad va de menor a mayor.*
#
# *Espero sea de utilidad para todos!*
#
# ***Empecemos:***

# %% [markdown]
# ![lluvias-y-Google.gif](data:image/gif;base64,...)

# %% [markdown]
# # **Archivo:**
# https://drive.google.com/file/d/10-VYQtSR7e5h5JPetByE_QsJCg-fH1ju/view?usp=sharing

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
mpl.style.use('bmh')

# %%
from google.colab import drive
drive.mount('/content/drive')
df=pd.read_csv('/content/drive/MyDrive/Archivos/pune_1965_to_2002.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df

# %%
df_lluvias = pd.read_csv('/content/pune_1965_to_2002.csv')
df_lluvias.head()
# Out:
#    Year    Jan    Feb    Mar     Apr  ...      Aug      Sep     Oct     Nov     Dec
# 0  1965  0.029  0.069  0.000  21.667  ...  402.521   69.511   5.249  16.232  22.075
# 1  1966  0.905  0.000  0.000   2.981  ...   59.386  150.624   1.308  41.214   4.132
# 2  1967  0.248  3.390  1.320  13.482  ...  181.069  183.757  50.404   8.393  37.685
# 3  1968  0.318  3.035  1.704  23.307  ...  171.979  219.884  73.997  23.326   2.020
# 4  1969  0.248  2.524  0.334   4.569  ...  397.335  205.413  24.014  24.385   1.951
#
# [5 rows x 13 columns]

# %%
df_lluvias.index = df_lluvias['Year']
df_lluvias = df_lluvias.drop('Year', axis='columns')
df_lluvias.head()
# Out:
#         Jan    Feb    Mar     Apr  ...      Sep     Oct     Nov     Dec
# Year                               ...
# 1965  0.029  0.069  0.000  21.667  ...   69.511   5.249  16.232  22.075
# 1966  0.905  0.000  0.000   2.981  ...  150.624   1.308  41.214   4.132
# 1967  0.248  3.390  1.320  13.482  ...  183.757  50.404   8.393  37.685
# 1968  0.318  3.035  1.704  23.307  ...  219.884  73.997  23.326   2.020
# 1969  0.248  2.524  0.334   4.569  ...  205.413  24.014  24.385   1.951
#
# [5 rows x 12 columns]

# %%
df_lluvias.isnull().sum(axis='columns')
# Out:
# Year
# 1965    0
# 1966    0
# 1967    0
# 1968    0
# 1969    0
# 1970    0
# 1971    0
# 1972    0
# 1973    0
# 1974    0
# 1975    0
# 1976    0
# 1977    0
# 1978    0
# 1979    0
# 1980    0
# 1981    0
# 1982    0
# 1983    0
# 1984    0
# 1985    0
# 1986    0
# 1987    0
# 1988    0
# 1989    0
# 1990    0
# 1991    0
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# dtype: int64

# %%
x = df_lluvias.index
y = df_lluvias.sum(axis='columns')
y
# Out:
# Year
# 1965    1263.394
# 1966     899.588
# 1967    1522.184
# 1968    1086.237
# 1969    1739.022
# 1970    1273.507
# 1971    1176.612
# 1972     710.475
# 1973    1570.073
# 1974    1425.876
# 1975    1777.838
# 1976    1941.167
# 1977    1202.154
# 1978    1168.583
# 1979    1769.187
# 1980    1268.185
# 1981    1562.761
# 1982     943.087
# 1983    1616.948
# 1984    1538.961
# 1985    1214.852
# 1986    1267.969
# 1987    1197.999
# 1988    1822.649
# 1989    1400.024
# 1990    1766.294
# 1991    1497.256
# 1992    1323.883
# 1993    1210.252
# 1994    1987.689
# 1995    1209.068
# 1996    1631.331
# 1997    1844.840
# 1998    1603.243
# 1999    1235.683
# 2000    1094.062
# 2001    1045.825
# 2002    1024.881
# dtype: float64

# %% [markdown]
# # Grafico de Lineas

# %%
ax.legend?

# %%
fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(x, y, label='Precipitaciones acumuladas')
ax.set_xlabel('Año')  				
ax.set_ylabel('Precipitación acumulada (mm.)')
ax.set_title('Precipitaciones acumuladas según el año')
ax.legend(loc='lower right')
ax.set_xlim(df_lluvias.index[0], df_lluvias.index[-1])
plt.show()

# %%
fig.savefig("precipitaciones_año.pdf")

# %%
df_lluvias.T.head()
# Out:
# Year    1965    1966    1967    1968  ...    1999    2000   2001    2002
# Jan    0.029   0.905   0.248   0.318  ...   0.000   0.000  0.147   0.231
# Feb    0.069   0.000   3.390   3.035  ...   1.431   0.170  0.000   0.911
# Mar    0.000   0.000   1.320   1.704  ...   0.000   0.000  2.178   0.388
# Apr   21.667   2.981  13.482  23.307  ...   0.642   1.193  1.528  53.266
# May   17.859  63.008  11.116   7.441  ...  35.828  26.237  7.860  18.430
#
# [5 rows x 38 columns]

# %%
x2 = df_lluvias.T.index
y2 = df_lluvias.T.sum(axis='columns')
y2
# Out:
# Jan       11.186
# Feb       41.843
# Mar       63.733
# Apr      470.487
# May      952.272
# Jun    12809.663
# Jul    16340.395
# Aug    10529.357
# Sep     7642.245
# Oct     2783.320
# Nov      958.492
# Dec      230.646
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(16, 6))
ax.plot(x2, y2, label='Precipitaciones acumuladas por mes')
ax.set_xlabel('Mes')  				
ax.set_ylabel('Precipitación acumulada (mm.)')
ax.set_title('Precipitaciones acumuladas según el mes')
ax.legend(loc='upper right')
plt.show()

# %%
fig.savefig("precipitaciones_mes.pdf")

# %% [markdown]
# # Grafico de Puntos

# %%
ax.scatter?

# %%
fig, ax = plt.subplots(figsize=(18, 10))  
mapeo_colores = ax.scatter(df_lluvias['Aug'], df_lluvias['Sep'], c=df_lluvias.index, s=50)
fig.colorbar(mapeo_colores)
ax.set_title('Precipitaciones Agosto-Septiembre')
ax.set_xlabel('Precipitaciones en Agosto (mm.)')
ax.set_ylabel('Precipitaciones en Septiembre (mm.)')
# Out:
# Text(0, 0.5, 'Precipitaciones en Septiembre (mm.)')

# %% [markdown]
# *No hay ninguna correlación entre los meses indicados*

# %%
fig, ax = plt.subplots(figsize=(15, 7))  
mapeo_colores = ax.scatter(df_lluvias['Jun'], df_lluvias['Jul'], c=df_lluvias.index, s=100)
fig.colorbar(mapeo_colores)
ax.set_title('Precipitaciones Junio-Julio')
ax.set_xlabel('Precipitaciones en Junio (mm.)')
ax.set_ylabel('Precipitaciones en Julio (mm.)')
# Out:
# Text(0, 0.5, 'Precipitaciones en Julio (mm.)')

# %% [markdown]
# *Hay una correlacion más fuerte..*

# %%
fig, ax = plt.subplots(figsize=(15, 7))  
mapeo_colores = ax.scatter(df_lluvias['Jan'], df_lluvias['Aug'], c=df_lluvias.index, s=200)
fig.colorbar(mapeo_colores)
ax.set_title('Precipitaciones Enero vs. Agosto')
ax.set_xlabel('Precipitaciones en Enero (mm.)')
ax.set_ylabel('Precipitaciones en Agosto (mm.)')
# Out:
# Text(0, 0.5, 'Precipitaciones en Agosto (mm.)')

# %% [markdown]
# **Aquí podemos observar una relación mucho más concisa:**
#
# *En la gran mayoria de los años, en el mes de enero se registraron pocas precipitaciones, cuando en el mes de Agosto del mismo año, se registraron muchas.*

# %% [markdown]
# # Grafico de Barras

# %%
fig, ax = plt.subplots(figsize=(12,6))
precipitaciones_acumuladas = df_lluvias.sum()
ax.bar(df_lluvias.columns, precipitaciones_acumuladas, color='green')
ax.set_title('Precipitaciones acumuladas desde 1965 a 2002, según el mes')
ax.set_ylabel('Precipitación total (mm.)')
ax.set_xlabel('Mes')
# Out:
# Text(0.5, 0, 'Mes')

# %% [markdown]
# # Histograma de Frecuencias

# %%
df_lluvias.values.flatten()
df_lluvias.values

# %%
fig, ax = plt.subplots(figsize=(14, 6))
ax.hist(df_lluvias.values.flatten(), bins=10)
ax.set_title('Histograma de precipitaciones acumuladas')
ax.set_xlabel('Intervalos de precipitaciones (mm.)')
ax.set_ylabel('Frecuencia absoluta')
# Out:
# Text(0, 0.5, 'Frecuencia absoluta')

# %%
df_lluvias.values.flatten().sum()
# Out:
# 52833.639

# %%
fig, ax = plt.subplots(figsize=(14, 6))
ax.hist(df_lluvias.values.flatten()/(df_lluvias.values.flatten().sum()) * 100, cumulative=True, density=True)
ax.set_title('Histograma de precipitaciones acumuladas, en valor porcentual respecto al total')
ax.set_xlabel('Intervalos de precipitaciones (mm.)')
ax.set_ylabel('Frecuencia relativa')
# Out:
# Text(0, 0.5, 'Frecuencia relativa')

# %% [markdown]
# # **Graficos con más elementos:**

# %% [markdown]
# **Precipitaciones de Enero vs. Febrero:**

# %%
fig, ax = plt.subplots(figsize=(16, 6))  
ax.plot(df_lluvias.index, df['Jan'], label='Precipitaciones de enero')
ax.plot(df_lluvias.index, df['Feb'], label='Precipitaciones de febrero', color='C1')

# %%
maximo_enero = df_lluvias['Jan'].max()
maximo_febrero =  df_lluvias['Feb'].max()

# %%
fig, ax = plt.subplots(figsize=(16, 6))  
ax.plot(df_lluvias.index, df['Jan'], label='Precipitaciones de enero', color='green', linewidth=5)
ax.plot(df_lluvias.index, df['Feb'], label='Precipitaciones de febrero', color='violet', linewidth=5)
ax.axhline(maximo_enero, color='black', linestyle='--', alpha=0.5,  linewidth=3, label='Máxima de enero')
ax.axhline(maximo_febrero, color='black', linestyle=':', alpha=0.5, linewidth=3, label='Máxima de febrero')

# %%
fig, ax = plt.subplots(figsize=(16, 6))  
ax.plot(df_lluvias.index, df['Jan'], label='Precipitaciones de enero', color='green', linewidth=5, alpha=0.7)
ax.plot(df_lluvias.index, df['Feb'], label='Precipitaciones de febrero', color='violet', linewidth=5, alpha=0.7)

ax.axhline(maximo_enero, color='black', linestyle='--', alpha=0.5,  linewidth=4, label='Máxima de enero')
ax.axhline(maximo_febrero, color='black', linestyle=':', alpha=0.5, linewidth=4, label='Máxima de febrero')

ax.set_xlabel('Año')  
ax.set_ylabel('Precipitación (mm.)') 
ax.set_title('Precipitaciones de enero y febrero') 	
ax.set_xlim(df_lluvias.index[0], df_lluvias.index[-1])
ax.legend(loc='upper right')

# %% [markdown]
# **Precipitaciones de Junio y Julio:**

# %%
maximo_junio = df_lluvias['Jun'].max()
maximo_julio =  df_lluvias['Jul'].max()
minimo_junio = df_lluvias['Jun'].min()
minimo_julio =  df_lluvias['Jul'].min()

promedio_junio= df_lluvias['Jun'].mean()
promedio_julio= df_lluvias['Jul'].mean()

# %%
fig, ax = plt.subplots(figsize=(16, 6))  
ax.plot(df_lluvias.index, df['Jun'], label='Precipitaciones de Junio', color='brown', linewidth=5, alpha=0.8)
ax.plot(df_lluvias.index, df['Jul'], label='Precipitaciones de Julio', color='orange', linewidth=5, alpha=0.8)

ax.axhline(maximo_junio, color='black', linestyle='--', alpha=0.5,  linewidth=4, label='Máx. de Junio')
ax.axhline(minimo_junio, color='grey', linestyle='--', alpha=0.5,  linewidth=4, label='Mín. de Junio')
ax.axhline(maximo_julio, color='black', linestyle=':', alpha=0.5, linewidth=4, label='Máx. de Julio')
ax.axhline(minimo_julio, color='grey', linestyle=':', alpha=0.5, linewidth=4, label='Mín. de Julio')
ax.axhline(promedio_junio, color='red', linestyle='--', alpha=0.5,  linewidth=4, label='Promedio de Junio')
ax.axhline(promedio_julio, color='orange', linestyle=':', alpha=0.5, linewidth=4, label='Promedio de Julio')

ax.set_xlabel('Año')  
ax.set_ylabel('Precipitación (mm.)') 
ax.set_title('Precipitaciones de junio y julio') 	
ax.set_xlim(df_lluvias.index[0], df_lluvias.index[-1])
ax.legend(loc='upper right')

# %% [markdown]
# *Este grafico no tiene el fin de presentación, sino demostrar las diferentes variables y etiquetas que pueden incluirse en un grafico. 💪*

# %% [markdown]
# # ***Muchas gracias!***
